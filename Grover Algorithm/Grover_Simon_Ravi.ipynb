# %%
def itera(qc):
    for i in range(6):
        if(pt[i] == 1):
            qc.x(l[i])
    
    qc.ccx(l[1],l[2],l[3])
    qc.cx(l[0],l[3])
    qc.cx(k[0],l[3])
    
    qc.ccx(l[2],l[0],l[4])
    qc.cx(l[1],l[4])
    qc.cx(k[1],l[4])

    qc.ccx(l[0],l[1],l[5])
    qc.cx(l[2],l[5])
    qc.cx(k[2],l[5])

    qc.ccx(l[4],l[5],l[0])
    qc.cx(l[3],l[0])
    qc.cx(k[3],l[0])

    qc.ccx(l[5],l[3],l[1])
    qc.cx(l[4],l[1])
    qc.cx(k[4],l[1])

    qc.ccx(l[3],l[4],l[2])
    qc.cx(l[5],l[2])
    qc.cx(k[5],l[2])

    qc.x(k[2])
        
    qc.cx(k[4],k[0])
    qc.cx(k[5],k[0])

    qc.cx(k[5],k[1])
    qc.cx(k[3],k[1])

    qc.cx(k[3],k[2])
    qc.cx(k[4],k[2])

    qc.x(k[5])

    qc.cx(k[1],k[3])
    qc.cx(k[2],k[3])

    qc.cx(k[2],k[4])
    qc.cx(k[0],k[4])

    qc.cx(k[0],k[5])
    qc.cx(k[1],k[5])

    qc.ccx(l[1],l[2],l[3])
    qc.cx(l[0],l[3])
    qc.cx(k[0],l[3])

    qc.ccx(l[2],l[0],l[4])
    qc.cx(l[1],l[4])
    qc.cx(k[1],l[4])

    qc.ccx(l[0],l[1],l[5])
    qc.cx(l[2],l[5])
    qc.cx(k[2],l[5])

    qc.ccx(l[4],l[5],l[0])
    qc.cx(l[3],l[0])
    qc.cx(k[3],l[0])

    qc.ccx(l[5],l[3],l[1])
    qc.cx(l[4],l[1])
    qc.cx(k[4],l[1])

    qc.ccx(l[3],l[4],l[2])
    qc.cx(l[5],l[2])
    qc.cx(k[5],l[2])
    
    
def invitera(qc):
    qc.ccx(l[3],l[4],l[2])
    qc.cx(l[5],l[2])
    qc.cx(k[5],l[2])
    
    qc.ccx(l[5],l[3],l[1])
    qc.cx(l[4],l[1])
    qc.cx(k[4],l[1])
    
    qc.ccx(l[4],l[5],l[0])
    qc.cx(l[3],l[0])
    qc.cx(k[3],l[0])
    
    qc.ccx(l[0],l[1],l[5])
    qc.cx(l[2],l[5])
    qc.cx(k[2],l[5])
    
    qc.ccx(l[2],l[0],l[4])
    qc.cx(l[1],l[4])
    qc.cx(k[1],l[4])
    
    qc.ccx(l[1],l[2],l[3])
    qc.cx(l[0],l[3])
    qc.cx(k[0],l[3])
    
    qc.cx(k[0],k[5])
    qc.cx(k[1],k[5])
    
    qc.cx(k[2],k[4])
    qc.cx(k[0],k[4])
    
    qc.cx(k[1],k[3])
    qc.cx(k[2],k[3])
    
    qc.x(k[5])
    
    qc.cx(k[3],k[2])
    qc.cx(k[4],k[2])
    
    qc.cx(k[5],k[1])
    qc.cx(k[3],k[1])
    
    qc.cx(k[4],k[0])
    qc.cx(k[5],k[0])
    
    qc.x(k[2])
    
    qc.ccx(l[3],l[4],l[2])
    qc.cx(l[5],l[2])
    qc.cx(k[5],l[2])
    
    qc.ccx(l[5],l[3],l[1])
    qc.cx(l[4],l[1])
    qc.cx(k[4],l[1])
    
    qc.ccx(l[4],l[5],l[0])
    qc.cx(l[3],l[0])
    qc.cx(k[3],l[0])
    
    qc.ccx(l[0],l[1],l[5])
    qc.cx(l[2],l[5])
    qc.cx(k[2],l[5])
    
    qc.ccx(l[2],l[0],l[4])
    qc.cx(l[1],l[4])
    qc.cx(k[1],l[4])
    
    qc.ccx(l[1],l[2],l[3])
    qc.cx(l[0],l[3])
    qc.cx(k[0],l[3])
    
    for i in range(6):
        if(pt[i] == 1):
            qc.x(l[i])
        
from qiskit import *
# %matplotlib inline
from qiskit import QuantumCircuit, QuantumRegister, ClassicalRegister, transpile
from qiskit.providers.basic_provider import BasicSimulator

from qiskit.tools.visualization import circuit_drawer
from qiskit.visualization import plot_histogram
import Our_Qiskit_Functions as oq
# simulator = Aer.get_backend('qasm_simulator')
# backend = AerSimulator(method="matrix_product_state")
backend = BasicSimulator()

l = QuantumRegister(6, name='l')
k = QuantumRegister(6, name='k')
trg = QuantumRegister(1, name = 'trg')
anc = QuantumRegister(4, name = 'anc')
c = ClassicalRegister(6, name='c')

qc = QuantumCircuit(l,k,trg,anc,c)

pt = [0,1,1,1,0,1]

for i in range(6):
    qc.h(k[i])
    
qc.x(trg[0])

for j in range(6):
    itera(qc)
    oq.Grover_Oracle([0,1,1,1,1,1], qc, l, trg, anc)
    invitera(qc)

    oq.Grover_Diffusion([0,0,0,0,0,0], qc, k, trg, anc)


for i in range(6):
    qc.measure(k[i],c[i])
        
job = transpile(qc, backend, shots=1024)
result = job.result()
counts = result.get_counts(qc)
print(counts)
plot_histogram(counts)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 157
#     154 from qiskit import QuantumCircuit, QuantumRegister, ClassicalRegister, transpile
#     155 from qiskit.providers.basic_provider import BasicSimulator
# --> 157 from qiskit.tools.visualization import circuit_drawer
#     158 from qiskit.visualization import plot_histogram
#     159 import Our_Qiskit_Functions as oq
#
# ModuleNotFoundError: No module named 'qiskit.tools'

# %%
import numpy as np
import math as m
import scipy as sci

def Grover_Oracle(mark, qc, q, an1, an2):
    '''
    Picks out the marked state and applies a negative phase
    '''
    qc.h(an1[0])
    X_Transformation(qc, q, mark)
    if(len(mark) > 2):
        n_NOT(qc, q, an1[0], an2)
    if(len(mark) == 2):
        qc.ccx(q[0], q[1], an1[0])
    X_Transformation(qc, q, mark)
    qc.h(an1[0])

    
def Grover_Diffusion(mark, qc, q, an1, an2):
    '''
    Ammends the instructions for a Grover Diffusion Operation to the QuantumCircuit
    '''
    zeros_state  = []
    for i in np.arange(len(mark)):
        zeros_state.append(0)
        qc.h(q[int(i)])
    Grover_Oracle(zeros_state, qc, q, an1, an2)
    for j in np.arange(len(mark)):
        qc.h(q[int(i)])
    

def X_Transformation(qc, qreg, state):
    '''
    Transforms ther state of the system, applying X gates according to 0's in the vector 'state'
    '''
    for j in np.arange(len(state)):
        if(int(state[j] == 0)):
            qc.x(qreg[int(j)])

            
def n_NOT(qc, control, target, anc):
    '''
    performs an n_NOT gate
    '''
    n = len(control)
    instructions = []
    active_ancilla = []
    q_unused = []
    q = 0
    a = 0
    while((n>0) or (len(q_unused)!= 0) or (len(active_ancilla) != 0)):
        if(n > 0):
            if((n-2) >= 0):
                instructions.append( [control[q], control[q+1], anc[a]] )
                active_ancilla.append(a)
                a = a+1
                q = q+2
                n = n-2
            if((n-2) == -1):
                q_unused.append(q)
                n = n-1
        elif(len(q_unused) != 0):
            if(len(active_ancilla) != 1):
                instructions.append([control[q], anc[active_ancilla[0]], anc[c]])
                del active_ancilla[0]
                del q_unused[0]
                active_ancilla.append(a)
                a = a+1
            else:
                instructions.append([control[q], anc[active_ancilla[0]], target])
                del active_ancilla[0]
                del q_unused[0]
        elif(len(active_ancilla) != 0):
            if(len(active_ancilla) > 2):
                instructions.append( [anc[active_ancilla[0]], anc[active_ancilla[1]], anc[a]] )
                active_ancilla.append(a)
                del active_ancilla[0]
                del active_ancilla[0]
                a = a+1
            elif( len(active_ancilla) == 2 ):
                instructions.append([anc[active_ancilla[0]], anc[active_ancilla[1]], target])
                del active_ancilla[0]
                del active_ancilla[0]
    for i in np.arange(len(instructions)):
        qc.ccx( instructions[i][0], instructions[i][1], instructions[i][2])
    del instructions[-1]
    for i in np.arange(len(instructions)):
        qc.ccx( instructions[0-(i+1)][0], instructions[0-(i+1)][1], instructions[0-(i+1)][2])

# %%
#Checking of the partial code segment

#from qiskit import *
# %matplotlib inline
from qiskit import QuantumCircuit, QuantumRegister, ClassicalRegister, Aer, execute
from qiskit.tools.visualization import circuit_drawer
from qiskit.visualization import plot_histogram
#import Our_Qiskit_Functions as oq
simulator = Aer.get_backend('qasm_simulator')

''' Ammending all the instructions for Grover search '''
l = QuantumRegister(6, name='l')
k = QuantumRegister(6, name='k')
trg = QuantumRegister(1, name = 'trg')
anc = QuantumRegister(4, name = 'anc')
c = ClassicalRegister(6, name='c')

qc = QuantumCircuit(l,k,trg,anc,c)

pt = [0,1,1,1,0,1]

for i in range(6):
    qc.h(k[i])
    
qc.x(trg[0])
#''' End of ammending all the instructions for Grover search '''

def itera(qc):
    for i in range(6):
        if(pt[i] == 1):
            qc.x(l[i])
    
    qc.ccx(l[1],l[2],l[3])
    qc.cx(l[0],l[3])
    qc.cx(k[0],l[3])
    
    qc.ccx(l[2],l[0],l[4])
    qc.cx(l[1],l[4])
    qc.cx(k[1],l[4])

    qc.ccx(l[0],l[1],l[5])
    qc.cx(l[2],l[5])
    qc.cx(k[2],l[5])

    qc.ccx(l[4],l[5],l[0])
    qc.cx(l[3],l[0])
    qc.cx(k[3],l[0])

    qc.ccx(l[5],l[3],l[1])
    qc.cx(l[4],l[1])
    qc.cx(k[4],l[1])

    qc.ccx(l[3],l[4],l[2])
    qc.cx(l[5],l[2])
    qc.cx(k[5],l[2])

    qc.x(k[2])
        
    qc.cx(k[4],k[0])
    qc.cx(k[5],k[0])

    qc.cx(k[5],k[1])
    qc.cx(k[3],k[1])

    qc.cx(k[3],k[2])
    qc.cx(k[4],k[2])

    qc.x(k[5])

    qc.cx(k[1],k[3])
    qc.cx(k[2],k[3])

    qc.cx(k[2],k[4])
    qc.cx(k[0],k[4])

    qc.cx(k[0],k[5])
    qc.cx(k[1],k[5])

    qc.ccx(l[1],l[2],l[3])
    qc.cx(l[0],l[3])
    qc.cx(k[0],l[3])

    qc.ccx(l[2],l[0],l[4])
    qc.cx(l[1],l[4])
    qc.cx(k[1],l[4])

    qc.ccx(l[0],l[1],l[5])
    qc.cx(l[2],l[5])
    qc.cx(k[2],l[5])

    qc.ccx(l[4],l[5],l[0])
    qc.cx(l[3],l[0])
    qc.cx(k[3],l[0])

    qc.ccx(l[5],l[3],l[1])
    qc.cx(l[4],l[1])
    qc.cx(k[4],l[1])

    qc.ccx(l[3],l[4],l[2])
    qc.cx(l[5],l[2])
    qc.cx(k[5],l[2])

# %%
#Code Continued...

def invitera(qc):
    qc.ccx(l[3],l[4],l[2])
    qc.cx(l[5],l[2])
    qc.cx(k[5],l[2])
    
    qc.ccx(l[5],l[3],l[1])
    qc.cx(l[4],l[1])
    qc.cx(k[4],l[1])
    
    qc.ccx(l[4],l[5],l[0])
    qc.cx(l[3],l[0])
    qc.cx(k[3],l[0])
    
    qc.ccx(l[0],l[1],l[5])
    qc.cx(l[2],l[5])
    qc.cx(k[2],l[5])
    
    qc.ccx(l[2],l[0],l[4])
    qc.cx(l[1],l[4])
    qc.cx(k[1],l[4])
    
    qc.ccx(l[1],l[2],l[3])
    qc.cx(l[0],l[3])
    qc.cx(k[0],l[3])
    
    qc.cx(k[0],k[5])
    qc.cx(k[1],k[5])
    
    qc.cx(k[2],k[4])
    qc.cx(k[0],k[4])
    
    qc.cx(k[1],k[3])
    qc.cx(k[2],k[3])
    
    qc.x(k[5])
    
    qc.cx(k[3],k[2])
    qc.cx(k[4],k[2])
    
    qc.cx(k[5],k[1])
    qc.cx(k[3],k[1])
    
    qc.cx(k[4],k[0])
    qc.cx(k[5],k[0])
    
    qc.x(k[2])
    
    qc.ccx(l[3],l[4],l[2])
    qc.cx(l[5],l[2])
    qc.cx(k[5],l[2])
    
    qc.ccx(l[5],l[3],l[1])
    qc.cx(l[4],l[1])
    qc.cx(k[4],l[1])
    
    qc.ccx(l[4],l[5],l[0])
    qc.cx(l[3],l[0])
    qc.cx(k[3],l[0])
    
    qc.ccx(l[0],l[1],l[5])
    qc.cx(l[2],l[5])
    qc.cx(k[2],l[5])
    
    qc.ccx(l[2],l[0],l[4])
    qc.cx(l[1],l[4])
    qc.cx(k[1],l[4])
    
    qc.ccx(l[1],l[2],l[3])
    qc.cx(l[0],l[3])
    qc.cx(k[0],l[3])
    
    for i in range(6):
        if(pt[i] == 1):
            qc.x(l[i])

# %%
#Code Continued...
''' Grover search portion '''
for i in range(6): #Hence, 6 is the number of iterations
    itera(qc)
    Grover_Oracle([0,1,1,1,1,1], qc, l, trg, anc)
    
    invitera(qc)
    Grover_Diffusion([0,0,0,0,0,0], qc, k, trg, anc)
#''' End of Grover search portion '''
#qc.draw('mpl')

# %%
qc.measure(k,c)
backend = Aer.get_backend('qasm_simulator') #To choose a suitable backend
job = backend.run(qc, shot = 1, memory=True) #To run the quantum program on the chosen backend
result = job.result() #To know the state
output = result.get_memory()[0]
print(output)
k1 = result.get_counts(qc)
print(k1)
plot_histogram(k1)
